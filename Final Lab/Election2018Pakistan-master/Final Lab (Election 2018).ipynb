# %%
import numpy as np
import pandas as pd
import keras
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('NA_Candidate_List.csv')
df
# Out:
#      District                     Seat Constituency_title  \
# 0     Chitral                  Chitral               NA-1
# 1     Chitral                  Chitral               NA-1
# 2     Chitral                  Chitral               NA-1
# 3     Chitral                  Chitral               NA-1
# 4     Chitral                  Chitral               NA-1
# 5     Chitral                  Chitral               NA-1
# 6     Chitral                  Chitral               NA-1
# 7     Chitral                  Chitral               NA-1
# 8     Chitral                  Chitral               NA-1
# 9     Chitral                  Chitral               NA-1
# 10    Chitral                  Chitral               NA-1
# 11       Swat                   Swat-I              NA-2
# 12       Swat                   Swat-I              NA-2
# 13       Swat                   Swat-I              NA-2
# 14       Swat                   Swat-I              NA-2
# ...

# %%
df['District']
# Out:
# 0       Chitral
# 1       Chitral
# 2       Chitral
# 3       Chitral
# 4       Chitral
# 5       Chitral
# 6       Chitral
# 7       Chitral
# 8       Chitral
# 9       Chitral
# 10      Chitral
# 11         Swat
# 12         Swat
# 13         Swat
# 14         Swat
# 15         Swat
# 16         Swat
# 17         Swat
# 18         Swat
# 19         Swat
# 20         Swat
# 21         Swat
# 22         Swat
# 23         Swat
# 24         Swat
# 25         Swat
# 26         Swat
# 27         Swat
# 28         Swat
# 29         Swat
#          ...
# 3151    Panjgur
# 3152    Panjgur
# 3153       Kech
# 3154       Kech
# 3155       Kech
# 3156       Kech
# 3157       Kech
# 3158       Kech
# 3159       Kech
# 3160       Kech
# 3161       Kech
# 3162       Kech
# 3163       Kech
# 3164       Kech
# 3165       Kech
# 3166       Kech
# 3167       Kech
# 3168    Lasbela
# 3169    Lasbela
# 3170    Lasbela
# 3171    Lasbela
# 3172    Lasbela
# 3173    Lasbela
# 3174    Lasbela
# ...

# %%
df.loc[df['District'] == 'Chitral']
# Out:
#    District     Seat Constituency_title                     Candidate_Name  \
# 0   Chitral  Chitral               NA-1                   lftikhar ud Din
# 1   Chitral  Chitral               NA-1                      Taqdira Ajmal
# 2   Chitral  Chitral               NA-1                    Saeed Ur Rehman
# 3   Chitral  Chitral               NA-1                        Saleem Khan
# 4   Chitral  Chitral               NA-1  Shahzada Muharamad Taimur Khisrao
# 5   Chitral  Chitral               NA-1                        Abdul Latif
# 6   Chitral  Chitral               NA-1                      Eid ulHussain
# 7   Chitral  Chitral               NA-1                     Mohammad Amjad
# 8   Chitral  Chitral               NA-1                     Muhammad Yahya
# 9   Chitral  Chitral               NA-1       Moulana Abdul Akbar Chitrali
# 10  Chitral  Chitral               NA-1                     Nisar Dastager
#
#                                       Party
# ...

# %%
df.loc[df['Candidate_Name'] == 'Imran Khan']
# Out:
#         District           Seat Constituency_title Candidate_Name Party
# 508  Tribal Area  Tribal Area-5              NA-44     Imran Khan   ANP

# %%
df.loc[df['Party'] == 'Pakistan Peoples Party Parliamentarians']
# Out:
#                                        District  \
# 3                                       Chitral
# 11                                         Swat
# 25                                         Swat
# 35                                         Swat
# 49                                    Upper Dir
# 51                                    Lower Dir
# 60                                    Lower Dir
# 67                                     Malakand
# 110   Kohistan-cum-Lower\nKolai Pallas Kohistan
# 114                                   Battagram
# 151                                Abbottabad-1
# 209                                       Swabi
# 216                                      Mardan
# 886                                     Chakwal
# 907                                      Gujrat
# 930                                      Gujrat
# 936                                      Gujrat
# 951                                      Gujrat
# ...

# %%
df.loc[df['Party'] == 'Pakistan Peoples Party Parliamentarians'].count()
# Out:
# District              75
# Seat                  75
# Constituency_title    75
# Candidate_Name        75
# Party                 75
# dtype: int64

# %%
df.loc[df['Party'] == 'Pakistan Muslim League(N)'].count()
# Out:
# District              18
# Seat                  18
# Constituency_title    18
# Candidate_Name        18
# Party                 18
# dtype: int64

# %%
df.groupby(['Party']).count()
# Out:
#                                          District  Seat  Constituency_title  \
# Party
#                                                 1     1                   1
# ALL PAKISTAN MUSLIM LEAGUE                      1     1                   1
# AMAL MUTTHIDA MAJLIS-EPAKISTAN                  1     1                   1
# ANP                                             2     2                   2
# APML                                            1     1                   1
# Aam Admi Tehreek Pakistan                       1     1                   1
# Aam Awam Party                                  2     2                   2
# Aam Log Party Pakistan                          4     4                   4
# Alah-o-oAkbar Tehreek                           1     1                   1
# All Pakistan Mishit) League                     1     1                   1
# All Pakistan Muslim                             1     1                   1
# ...

# %%
df.groupby(['Party']).max()
# Out:
#                                                                           District  \
# Party
#                                                                           Karachi
# ALL PAKISTAN MUSLIM LEAGUE                               Toba Tek Sing
# AMAL MUTTHIDA MAJLIS-EPAKISTAN                                         Sheikhupura
# ANP                                                                    Tribal Area
# APML                                                                     Islamabad
# Aam Admi Tehreek Pakistan                                          Dera Ghazi Khan
# Aam Awam Party                                                               Kasur
# Aam Log Party Pakistan                                             Mandi Bahauddin
# Alah-o-oAkbar Tehreek                                       Mnnsehra? culn Torghar
# All Pakistan Mishit) League                                            Sheikhupura
# ...

# %%
df.groupby(["District"])[['Candidate_Name']].count()
# Out:
#                            Candidate_Name
# District
# Abbottabad-1                           13
# Abbottabad-2                           18
# Attock                                  8
# Badin                                  14
# Bahawalnagar                           41
# Bahawalpur                             41
# Bannu                                  12
# Battagram                               8
# Bhakkar                                19
# Buner                                   7
# Chagai                                 18
# Chakwal                                21
# Charsaddah                             17
# Chiniot                                23
# Chitral                                11
# Dadu                                   16
# Dera                                   31
# Dera Ghazi Khan                        39
# Dera Ismail Khan                       29
# Faisalabad                            111
# Ghotki                                 19
# ...

# %%
df.groupby(["Party"])[['Candidate_Name']].count()
# Out:
#                                          Candidate_Name
# Party
#                                                       1
# ALL PAKISTAN MUSLIM LEAGUE                            1
# AMAL MUTTHIDA MAJLIS-EPAKISTAN                        1
# ANP                                                   2
# APML                                                  1
# Aam Admi Tehreek Pakistan                             1
# Aam Awam Party                                        2
# Aam Log Party Pakistan                                4
# Alah-o-oAkbar Tehreek                                 1
# All Pakistan Mishit) League                           1
# All Pakistan Muslim                                   1
# All Pakistan Muslim League                           32
# All Pakistan Muslim League                            6
# All Pakistan Muslim League (Jinnah)                   1
# All Pakistan Muslim League(jinnah)                    1
# All Pakistan Muslim league                            1
# ...

# %%
df.groupby(["District"])[['Candidate_Name']].max().count()
# Out:
# Candidate_Name    108
# dtype: int64

# %%
len(df['Party'].unique())
# Out:
# 332

# %%
df.groupby(["Party"])[['Candidate_Name']].count().max()
# Out:
# Candidate_Name    1086
# dtype: int64

# %%
df.groupby('Party').count()['Candidate_Name'].idxmax()
# Out:
# 'Independent'

# %%
df.groupby('Constituency_title').count()['Candidate_Name'].idxmax()
# Out:
# 'NA-45'

# %%
df.groupby('Constituency_title').count()['Candidate_Name'].idxmin()
# Out:
# 'NA-18'
