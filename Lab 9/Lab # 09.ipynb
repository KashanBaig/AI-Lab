# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('international-airline-passengers.csv')

# %%
plt.plot(df.Passengers)
plt.show()

# %%
p = df.Passengers

# %%
i = 0 
seq_x = []
seq_y = []
while i+5<len(p):
    seq_x.append(p[i:i+4])
    seq_y.append(p[i+4])
    i = i+1

# %%
x = np.array(seq_x)
y = np.array(seq_y)
x
# Out:
# array([[112., 118., 132., 129.],
#        [118., 132., 129., 121.],
#        [132., 129., 121., 135.],
#        [129., 121., 135., 148.],
#        [121., 135., 148., 148.],
#        [135., 148., 148., 136.],
#        [148., 148., 136., 119.],
#        [148., 136., 119., 104.],
#        [136., 119., 104., 118.],
#        [119., 104., 118., 115.],
#        [104., 118., 115., 126.],
#        [118., 115., 126., 141.],
#        [115., 126., 141., 135.],
#        [126., 141., 135., 125.],
#        [141., 135., 125., 149.],
#        [135., 125., 149., 170.],
#        [125., 149., 170., 170.],
#        [149., 170., 170., 158.],
#        [170., 170., 158., 133.],
#        [170., 158., 133., 114.],
#        [158., 133., 114., 140.],
#        [133., 114., 140., 145.],
#        [114., 140., 145., 150.],
#        [140., 145., 150., 178.],
#        [145., 150., 178., 163.],
#        [150., 178., 163., 172.],
#        [178., 163., 172., 178.],
#        [163., 172., 178., 199.],
# ...
